# %%
import numpy
import torch
import scipy
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
import numpy as np
import os
from keras.layers import Input, Lambda, Dense
from keras.models import Model
import keras.backend as K
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f90e96756fc8> in <module>()
#       1 import numpy
# ----> 2 import torch
#       3 import scipy
#       4 import torch.nn as nn
#       5 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %%
embed = hub.Module("https://tfhub.dev/google/universal-sentence-encoder/2")
elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)

# def UniversalEmbedding(x):
#     return embed(tf.squeeze(tf.cast(x, tf.string)))
# def ElmoEmbedding(x):
#     return elmo_model(tf.squeeze(tf.cast(x, tf.string)), signature="default", as_dict=True)["default"]

df=pd.read_csv("snopes_final300.csv",sep='\t')
def UniversalEmbedding(x):
    return embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
for i,row in df.iterrows():
        claim=row['claim']
        article=row['article']
        input_text = Input(shape=(1,), dtype=tf.string)
        embedding = Lambda(UniversalEmbedding, output_shape=(512, ))(input_text)
        with tf.Session() as session:
            session.run([tf.global_variables_initializer(), tf.tables_initializer()])
            message_embeddings = session.run(embedding)
        break
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# NotFoundError: No registered 'Size' OpKernel for GPU devices compatible with node {{node lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Prod}} = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](lambda_2/module_6_apply_default/compound_bigrams/concat_2/_283, ^lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Shape_1/_287)
# 	 (OpKernel was found, but attributes didn't match)
# 	.  Registered:  device='XLA_CPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, DT_COMPLEX64, DT_INT64, DT_BOOL, DT_QINT8, DT_QUINT8, DT_QINT32, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_GPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, ..., DT_QINT32, DT_BFLOAT16, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_CPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_CPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_GPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_GPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='CPU'; out_type in [DT_INT64]
#   device='CPU'; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT32]
#
# 	 [[{{node lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Prod}} = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](lambda_2/module_6_apply_default/compound_bigrams/concat_2/_283, ^lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Shape_1/_287)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-12-4323e4ba2bd2> in <module>()
#       6         with tf.Session() as session:
#       7             session.run([tf.global_variables_initializer(), tf.tables_initializer()])
# ----> 8             message_embeddings = session.run(embedding)
#       9         break
#      10
#
# ~/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# NotFoundError: No registered 'Size' OpKernel for GPU devices compatible with node node lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow_hub/native_module.py:447)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](lambda_2/module_6_apply_default/compound_bigrams/concat_2/_283, ^lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Shape_1/_287)
# 	 (OpKernel was found, but attributes didn't match)
# 	.  Registered:  device='XLA_CPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, DT_COMPLEX64, DT_INT64, DT_BOOL, DT_QINT8, DT_QUINT8, DT_QINT32, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_GPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, ..., DT_QINT32, DT_BFLOAT16, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_CPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_CPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_GPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_GPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='CPU'; out_type in [DT_INT64]
#   device='CPU'; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT32]
#
# 	 [[node lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow_hub/native_module.py:447)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](lambda_2/module_6_apply_default/compound_bigrams/concat_2/_283, ^lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Shape_1/_287)]]
#
# Caused by op 'lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Prod', defined at:
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-4323e4ba2bd2>", line 5, in <module>
#     embedding = Lambda(UniversalEmbedding, output_shape=(512, ))(input_text)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/keras/engine/base_layer.py", line 457, in __call__
#     output = self.call(inputs, **kwargs)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/keras/layers/core.py", line 687, in call
#     return self.function(inputs, **arguments)
#   File "<ipython-input-10-48bc5b7304fa>", line 11, in UniversalEmbedding
#     return embed(tf.squeeze(tf.cast(x, tf.string)))
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow_hub/module.py", line 203, in __call__
#     name=name)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow_hub/native_module.py", line 447, in create_apply_graph
#     restore_collections_predicate=(lambda key: key in import_collections))
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1674, in import_meta_graph
#     meta_graph_or_file, clear_devices, import_scope, **kwargs)[0]
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1696, in _import_meta_graph_with_return_elements
#     **kwargs))
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/framework/meta_graph.py", line 806, in import_scoped_meta_graph_with_return_elements
#     return_elements=return_elements)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/framework/importer.py", line 442, in import_graph_def
#     _ProcessNewOps(graph)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/framework/importer.py", line 234, in _ProcessNewOps
#     for new_op in graph._add_new_tf_operations(compute_devices=False):  # pylint: disable=protected-access
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3440, in _add_new_tf_operations
#     for c_op in c_api_util.new_tf_operations(self)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3440, in <listcomp>
#     for c_op in c_api_util.new_tf_operations(self)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3299, in _create_op_from_tf_operation
#     ret = Operation(c_op, self)
#   File "/home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): No registered 'Size' OpKernel for GPU devices compatible with node node lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow_hub/native_module.py:447)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](lambda_2/module_6_apply_default/compound_bigrams/concat_2/_283, ^lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Shape_1/_287)
# 	 (OpKernel was found, but attributes didn't match)
# 	.  Registered:  device='XLA_CPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, DT_COMPLEX64, DT_INT64, DT_BOOL, DT_QINT8, DT_QUINT8, DT_QINT32, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_GPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, ..., DT_QINT32, DT_BFLOAT16, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_CPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_CPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_GPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_GPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='CPU'; out_type in [DT_INT64]
#   device='CPU'; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT32]
#
# 	 [[node lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/sanjay/anaconda3/envs/IR/lib/python3.6/site-packages/tensorflow_hub/native_module.py:447)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](lambda_2/module_6_apply_default/compound_bigrams/concat_2/_283, ^lambda_2/module_6_apply_default/compound_bigrams/boolean_mask/Shape_1/_287)]]
